# %% [markdown]
# Import Necessary Modules

# %%
import sys
import os
import pandas as pd

# Add the path to the scripts directory
sys.path.append(os.path.abspath('../../scripts'))

# Import the DataPreprocessor class
from data_preprocessor import DataPreprocessor

# %% [markdown]
# Define Input and Output Paths and Initialize the DataPreprocessor

# %%
input_path = '../../src/Data/raw_data/modernshoppingcenter-data.csv'
output_path = '../../src/Data/clean_data/modernshoppingcenter_clean_data.csv'

# Initialize the DataPreprocessor
preprocessor = DataPreprocessor(input_path, output_path)

# %% [markdown]
# Load the Data

# %%
preprocessor.load_data()

# Print the shape and DataFrame after loading the data
print("Shape before preprocessing:", preprocessor.df.shape)
print("Data after loading:")
preprocessor.df
# Out:
# Data loaded successfully.
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 3057
# Shape before preprocessing: (4793, 5)
# Data after loading:
#                               Channel Title       Channel Username    ID  \
# 0     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5382
# 1     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5381
# 2     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5380
# 3     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5379
# 4     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5378
# ...                                     ...                    ...   ...
# 4788  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     8
# 4789  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     6
# 4790  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     5
# ...

# %% [markdown]
# Preprocess the Data

# %%
preprocessor.preprocess_data()

# Print the shape and DataFrame after preprocessing the data
print("Shape after preprocessing:", preprocessor.df.shape)
print("Data after preprocessing:")
preprocessor.df
# Out:
# Data preprocessing completed.
# Shape after preprocessing: (1736, 6)
# Data after preprocessing:
#                               Channel Title       Channel Username    ID  \
# 3     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5379
# 8     ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5374
# 12    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5370
# 16    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5366
# 17    ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter  5365
# ...                                     ...                    ...   ...
# 4785  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter    11
# 4787  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     9
# 4788  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     8
# 4789  ሞደርን ሾፒንግ ሴንተር MODERN SHOPPING CENTER  @modernshoppingcenter     6
# ...

# %% [markdown]
# Save the Cleaned Data

# %%
# Save the Cleaned Data
preprocessor.save_data()
# Out:
# Cleaned text saved to ../../src/Data/clean_data/modernshoppingcenter_clean_data.csv.
