# %% [markdown]
# Import Necessary Modules

# %%
import sys
import os
import pandas as pd

# Add the path to the scripts directory
sys.path.append(os.path.abspath('../../scripts'))

# Import the DataPreprocessor class
from data_preprocessor import DataPreprocessor

# %% [markdown]
# Define Input and Output Paths and Initialize the DataPreprocessor

# %%
input_path = '../../src/Data/raw_data/ZemenExpress-data.csv'
output_path = '../../src/Data/clean_data/zemenExpress_clean_data.csv'

# Initialize the DataPreprocessor
preprocessor = DataPreprocessor(input_path, output_path)

# %% [markdown]
# Load the Data

# %%
preprocessor.load_data()

# Print the shape and DataFrame after loading the data
print("Shape before preprocessing:", preprocessor.df.shape)
print("Data after loading:")
preprocessor.df
# Out:
# Data loaded successfully.
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 1129
# Shape before preprocessing: (5000, 5)
# Data after loading:
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  6029
# 1     Zemen Express®    @ZemenExpress  6028
# 2     Zemen Express®    @ZemenExpress  6027
# 3     Zemen Express®    @ZemenExpress  6026
# 4     Zemen Express®    @ZemenExpress  6025
# ...              ...              ...   ...
# 4995  Zemen Express®    @ZemenExpress   850
# 4996  Zemen Express®    @ZemenExpress   849
# 4997  Zemen Express®    @ZemenExpress   848
# 4998  Zemen Express®    @ZemenExpress   847
# 4999  Zemen Express®    @ZemenExpress   846
#
#                                                 Message  \
# 0     💥💥...................................💥💥\n\n🎯El...
# 1     💥💥...................................💥💥\n\n🎯El...
# 2     💥💥...............👸................💥💥\n\n📌Strai...
# 3     💥💥...............👸................💥💥\n\n📌Strai...
# 4     💥💥...............👸................💥💥\n\n📌Strai...
# ...                                                 ...
# 4995  🎯 Long Sewer Cleaning Wire Spring\n\n🏢 አድራሻ👉 መ...
# 4996                                                NaN
# 4997                                                NaN
# 4998                                                NaN
# 4999  🎯 Long Sewer Cleaning Wire Spring\n\n🔰Bringing...
#
#                            Date
# 0     2025-01-17 11:14:54+00:00
# 1     2025-01-17 11:14:44+00:00
# 2     2025-01-17 09:19:54+00:00
# 3     2025-01-17 09:19:43+00:00
# 4     2025-01-17 09:19:26+00:00
# ...                         ...
# 4995  2021-11-03 08:50:45+00:00
# 4996  2021-11-03 08:48:12+00:00
# 4997  2021-11-03 08:48:12+00:00
# 4998  2021-11-03 08:48:12+00:00
# 4999  2021-11-03 08:48:12+00:00
#
# [5000 rows x 5 columns]

# %% [markdown]
# Preprocess the Data

# %%
preprocessor.preprocess_data()

# Print the shape and DataFrame after preprocessing the data
print("Shape after preprocessing:", preprocessor.df.shape)
print("Data after preprocessing:")
preprocessor.df
# Out:
# Data preprocessing completed.
# Shape after preprocessing: (3871, 6)
# Data after preprocessing:
#        Channel Title Channel Username    ID  \
# 0     Zemen Express®    @ZemenExpress  6029
# 1     Zemen Express®    @ZemenExpress  6028
# 2     Zemen Express®    @ZemenExpress  6027
# 3     Zemen Express®    @ZemenExpress  6026
# 4     Zemen Express®    @ZemenExpress  6025
# ...              ...              ...   ...
# 4992  Zemen Express®    @ZemenExpress   855
# 4993  Zemen Express®    @ZemenExpress   854
# 4994  Zemen Express®    @ZemenExpress   852
# 4995  Zemen Express®    @ZemenExpress   850
# 4999  Zemen Express®    @ZemenExpress   846
#
#                                                 Message  \
# 0     ...................................\n\nElectri...
# 1     ...................................\n\nElectri...
# 2     ...............................\n\nStraight Co...
# 3     ...............................\n\nStraight Co...
# 4     ...............................\n\nStraight Co...
# ...                                                 ...
# 4992   Adjustable Posture Corrector\n  \nCorrector B...
# 4993  Cyber 4 in1  CYSB-3324, Electric Stick Blender...
# 4994   Hair dryer gw 6509 1600w\n\n ዋጋ፦    900 ብር\n\...
# 4995   Long Sewer Cleaning Wire Spring\n\n አድራሻ መገናኛ...
# 4999   Long Sewer Cleaning Wire Spring\n\nBringing m...
#
#                            Date  \
# 0     2025-01-17 11:14:54+00:00
# 1     2025-01-17 11:14:44+00:00
# 2     2025-01-17 09:19:54+00:00
# 3     2025-01-17 09:19:43+00:00
# 4     2025-01-17 09:19:26+00:00
# ...                         ...
# 4992  2021-11-10 09:08:42+00:00
# 4993  2021-11-06 18:55:40+00:00
# 4994  2021-11-06 08:30:57+00:00
# 4995  2021-11-03 08:50:45+00:00
# 4999  2021-11-03 08:48:12+00:00
#
#                                         Cleaned_Message
# 0     \n\n    \n            \n\nየፀጉር እስቲመር ትሪትመንት ወይ...
# 1     \n\n    \n            \n\nየፀጉር እስቲመር ትሪትመንት ወይ...
# 2     \n\n   \n\nምንም አይነት ድምፅ የሌለው \n\nሁሉንም አይነት ጸጉር...
# 3     \n\n   \n\nምንም አይነት ድምፅ የሌለው \n\nሁሉንም አይነት ጸጉር...
# 4     \n\n   \n\nምንም አይነት ድምፅ የሌለው \n\nሁሉንም አይነት ጸጉር...
# ...                                                 ...
# 4992     \n  \n \n    \n\nየአንገት፣የትከሻ እና የወገብ ህመምን የሚ...
# 4993             & \n\n    \n   \n\nከማይዝግ ብረት እና ከጠን...
# 4994       \n\n ዋጋ፦     ብር\n\n አድራሻ መገናኛ ደራርቱ ህንፃ ጎን...
# 4995       \n\n አድራሻ መገናኛ ደራርቱ ህንፃ ጎን መሰረት ደፋር ሞል ሁለ...
# 4999       \n\n         \n\n     \n     \n      \n  ...
#
# [3871 rows x 6 columns]

# %% [markdown]
# Save the Cleaned Data

# %%
# Save the Cleaned Data
preprocessor.save_data()
# Out:
# Cleaned text saved to ../../src/Data/clean_data/zemenExpress_clean_data.csv.
