# %% [markdown]
# Import Necessary Modules

# %%
import sys
import os
import pandas as pd

# Add the path to the scripts directory
sys.path.append(os.path.abspath('../../scripts'))

# Import the DataPreprocessor class
from data_preprocessor import DataPreprocessor

# %% [markdown]
# Define Input and Output Paths and Initialize the DataPreprocessor

# %%
input_path = '../../src/Data/raw_data/qnashcom-data.csv'
output_path = '../../src/Data/clean_data/qnashcom_clean_data.csv'

# Initialize the DataPreprocessor
preprocessor = DataPreprocessor(input_path, output_path)

# %% [markdown]
# Load the Data

# %%
preprocessor.load_data()

# Print the shape and DataFrame after loading the data
print("Shape before preprocessing:", preprocessor.df.shape)
print("Data after loading:")
preprocessor.df
# Out:
# Data loaded successfully.
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 331
# Shape before preprocessing: (3600, 5)
# Data after loading:
#            Channel Title Channel Username    ID  \
# 0     qnash.com - ቅናሽ ®️        @qnashcom  4404
# 1     qnash.com - ቅናሽ ®️        @qnashcom  4403
# 2     qnash.com - ቅናሽ ®️        @qnashcom  4402
# 3     qnash.com - ቅናሽ ®️        @qnashcom  4401
# 4     qnash.com - ቅናሽ ®️        @qnashcom  4400
# ...                  ...              ...   ...
# 3595  qnash.com - ቅናሽ ®️        @qnashcom    20
# 3596  qnash.com - ቅናሽ ®️        @qnashcom    19
# 3597  qnash.com - ቅናሽ ®️        @qnashcom    18
# 3598  qnash.com - ቅናሽ ®️        @qnashcom    17
# 3599  qnash.com - ቅናሽ ®️        @qnashcom     1
#
#                                                 Message  \
# 0     📣 Hair Steamer Cap\n🔼 High Quality \n\n➡️የፀጉር ...
# 1     📣 Hair Steamer Cap\n🔼 High Quality \n\n➡️የፀጉር ...
# 2     🟰🔡🔣🟰ለደረቅ ነገሮች መፍጫ የቀረበ\n➡️GRINDER Machine \n➡️...
# 3     🟰🔡🔣🟰ለደረቅ ነገሮች መፍጫ የቀረበ\n➡️GRINDER Machine \n➡️...
# 4     🔥🔥 Saachi Touch Stove Ceramic Cooker\n\n📣 ባለ አ...
# ...                                                 ...
# 3595  👔የልብስ መተኮሻ ቴብል ከ ኦርጅናል ስቲም ካውያ ጋር \n  -የራሱ መቆጣ...
# 3596  🚫ቤትዎን ከአይጥ 🐀 ከበረሮ🕷 እና ከተባይ🐜 🚫\n               ...
# 3597  😍  ታላቅ ቅናሽ 😍\nዘመናዊ መደርደሪያው ብረት የሆነ ጫማ መደርደሪያ\n...
# 3598                                                NaN
# 3599                                                NaN
#
#                            Date
# 0     2025-01-17 16:41:32+00:00
# 1     2025-01-17 11:35:59+00:00
# 2     2025-01-17 09:01:41+00:00
# 3     2025-01-17 09:01:41+00:00
# 4     2025-01-17 05:14:52+00:00
# ...                         ...
# 3595  2020-08-26 02:44:03+00:00
# 3596  2020-08-26 02:32:16+00:00
# 3597  2020-08-26 02:16:56+00:00
# 3598  2020-08-25 17:14:43+00:00
# 3599  2020-05-22 04:16:48+00:00
#
# [3600 rows x 5 columns]

# %% [markdown]
# Preprocess the Data

# %%
preprocessor.preprocess_data()

# Print the shape and DataFrame after preprocessing the data
print("Shape after preprocessing:", preprocessor.df.shape)
print("Data after preprocessing:")
preprocessor.df
# Out:
# Data preprocessing completed.
# Shape after preprocessing: (3269, 6)
# Data after preprocessing:
#            Channel Title Channel Username    ID  \
# 0     qnash.com - ቅናሽ ®️        @qnashcom  4404
# 1     qnash.com - ቅናሽ ®️        @qnashcom  4403
# 2     qnash.com - ቅናሽ ®️        @qnashcom  4402
# 3     qnash.com - ቅናሽ ®️        @qnashcom  4401
# 4     qnash.com - ቅናሽ ®️        @qnashcom  4400
# ...                  ...              ...   ...
# 3593  qnash.com - ቅናሽ ®️        @qnashcom    23
# 3594  qnash.com - ቅናሽ ®️        @qnashcom    22
# 3595  qnash.com - ቅናሽ ®️        @qnashcom    20
# 3596  qnash.com - ቅናሽ ®️        @qnashcom    19
# 3597  qnash.com - ቅናሽ ®️        @qnashcom    18
#
#                                                 Message  \
# 0      Hair Steamer Cap\n High Quality \n\nየፀጉር እስቲመ...
# 1      Hair Steamer Cap\n High Quality \n\nየፀጉር እስቲመ...
# 2     ለደረቅ ነገሮች መፍጫ የቀረበ\nGRINDER Machine \nየቡና እና የ...
# 3     ለደረቅ ነገሮች መፍጫ የቀረበ\nGRINDER Machine \nየቡና እና የ...
# 4      Saachi Touch Stove Ceramic Cooker\n\n ባለ አንድ ...
# ...                                                 ...
# 3593  አስደሳች ዜና \nFoot bath massager\nብዙ ጊዜ በስራ ላይ የሚ...
# 3594  አስደሳች ዜና \n\nCerotti የፀጉር ማድረቂያ\n\nበጣልያን የሚመረት...
# 3595  የልብስ መተኮሻ ቴብል ከ ኦርጅናል ስቲም ካውያ ጋር \n  -የራሱ መቆጣጠ...
# 3596  ቤትዎን ከአይጥ  ከበረሮ እና ከተባይ \n                ነፃ ያ...
# 3597    ታላቅ ቅናሽ \nዘመናዊ መደርደሪያው ብረት የሆነ ጫማ መደርደሪያ\n\n...
#
#                            Date  \
# 0     2025-01-17 16:41:32+00:00
# 1     2025-01-17 11:35:59+00:00
# 2     2025-01-17 09:01:41+00:00
# 3     2025-01-17 09:01:41+00:00
# 4     2025-01-17 05:14:52+00:00
# ...                         ...
# 3593  2020-08-26 03:25:39+00:00
# 3594  2020-08-26 02:55:07+00:00
# 3595  2020-08-26 02:44:03+00:00
# 3596  2020-08-26 02:32:16+00:00
# 3597  2020-08-26 02:16:56+00:00
#
#                                         Cleaned_Message
# 0        \n   \n\nየፀጉር እስቲመር ትሪትመንት ወይም ቅቤ ተቀብተው በቤቶ...
# 1        \n   \n\nየፀጉር እስቲመር ትሪትመንት ወይም ቅቤ ተቀብተው በቤቶ...
# 2     ለደረቅ ነገሮች መፍጫ የቀረበ\n  \nየቡና እና የቅመማ ቅመም መፍጫ \n...
# 3     ለደረቅ ነገሮች መፍጫ የቀረበ\n  \nየቡና እና የቅመማ ቅመም መፍጫ \n...
# 4          \n\n ባለ አንድ \n      \n    \n    \n   \n  ...
# ...                                                 ...
# 3593  አስደሳች ዜና \n  \nብዙ ጊዜ በስራ ላይ የሚቆሙ ሰዎች ፣ የተረከዝ መ...
# 3594  አስደሳች ዜና \n\n የፀጉር ማድረቂያ\n\nበጣልያን የሚመረት አንደኛ ደ...
# 3595  የልብስ መተኮሻ ቴብል ከ ኦርጅናል ስቲም ካውያ ጋር \n  የራሱ መቆጣጠሪ...
# 3596  ቤትዎን ከአይጥ  ከበረሮ እና ከተባይ \n                ነፃ ያ...
# 3597    ታላቅ ቅናሽ \nዘመናዊ መደርደሪያው ብረት የሆነ ጫማ መደርደሪያ\n\n...
#
# [3269 rows x 6 columns]

# %% [markdown]
# Save the Cleaned Data

# %%
# Save the Cleaned Data
preprocessor.save_data()
# Out:
# Cleaned text saved to ../../src/Data/clean_data/qnashcom_clean_data.csv.
