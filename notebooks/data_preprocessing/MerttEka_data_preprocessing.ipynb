# %% [markdown]
# Import Necessary Modules

# %%
import sys
import os
import pandas as pd

# Add the path to the scripts directory
sys.path.append(os.path.abspath('../../scripts'))

# Import the DataPreprocessor class
from data_preprocessor import DataPreprocessor

# %% [markdown]
# Define Input and Output Paths and Initialize the DataPreprocessor

# %%
input_path = '../../src/Data/raw_data/MerttEka-data.csv'
output_path = '../../src/Data/clean_data/MerttEka_clean_data.csv'

# Initialize the DataPreprocessor
preprocessor = DataPreprocessor(input_path, output_path)

# %% [markdown]
# Load the Data

# %%
preprocessor.load_data()

# Print the shape and DataFrame after loading the data
print("Shape before preprocessing:", preprocessor.df.shape)
print("Data after loading:")
preprocessor.df
# Out:
# Data loaded successfully.
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 1379
# Shape before preprocessing: (5000, 5)
# Data after loading:
#      Channel Title Channel Username    ID  \
# 0           ምርጥ ዕቃ        @MerttEka  7453
# 1           ምርጥ ዕቃ        @MerttEka  7452
# 2           ምርጥ ዕቃ        @MerttEka  7451
# 3           ምርጥ ዕቃ        @MerttEka  7448
# 4           ምርጥ ዕቃ        @MerttEka  7447
# ...            ...              ...   ...
# 4995        ምርጥ ዕቃ        @MerttEka  1723
# 4996        ምርጥ ዕቃ        @MerttEka  1721
# 4997        ምርጥ ዕቃ        @MerttEka  1720
# 4998        ምርጥ ዕቃ        @MerttEka  1719
# 4999        ምርጥ ዕቃ        @MerttEka  1717
#
#                                                 Message  \
# 0                                                   NaN
# 1                                                   NaN
# 2     📣 Cryatal Glass Ice Bucket\n\n✔️ የበረዶ መያዢያ ባልዲ...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4995  STAINLESS STEEL  COOKWARE SET\n👉18cm; 20cm; 22...
# 4996                            Kenwood portable juicer
# 4997  Kenwood portable blender\n👉በቻርጅ የሚሰራ\n👉 380ሚሊ ...
# 4998  PRANDELI ITALY COOKWARE\n👉 ማብሰያና ወጥ ማቅረቢያ የሚሆኑ...
# 4999                                       Garlic Press
#
#                            Date
# 0     2025-01-17 16:43:06+00:00
# 1     2025-01-17 16:43:05+00:00
# 2     2025-01-17 16:43:05+00:00
# 3     2025-01-16 20:20:43+00:00
# 4     2025-01-16 20:20:43+00:00
# ...                         ...
# 4995  2022-03-26 16:13:36+00:00
# 4996  2022-03-26 04:03:35+00:00
# 4997  2022-03-25 13:53:28+00:00
# 4998  2022-03-25 10:49:06+00:00
# 4999  2022-03-22 15:53:43+00:00
#
# [5000 rows x 5 columns]

# %% [markdown]
# Preprocess the Data

# %%
preprocessor.preprocess_data()

# Print the shape and DataFrame after preprocessing the data
print("Shape after preprocessing:", preprocessor.df.shape)
print("Data after preprocessing:")
preprocessor.df
# Out:
# Data preprocessing completed.
# Shape after preprocessing: (3621, 6)
# Data after preprocessing:
#      Channel Title Channel Username    ID  \
# 2           ምርጥ ዕቃ        @MerttEka  7451
# 5           ምርጥ ዕቃ        @MerttEka  7445
# 8           ምርጥ ዕቃ        @MerttEka  7442
# 11          ምርጥ ዕቃ        @MerttEka  7439
# 12          ምርጥ ዕቃ        @MerttEka  7437
# ...            ...              ...   ...
# 4995        ምርጥ ዕቃ        @MerttEka  1723
# 4996        ምርጥ ዕቃ        @MerttEka  1721
# 4997        ምርጥ ዕቃ        @MerttEka  1720
# 4998        ምርጥ ዕቃ        @MerttEka  1719
# 4999        ምርጥ ዕቃ        @MerttEka  1717
#
#                                                 Message  \
# 2      Cryatal Glass Ice Bucket\n\n የበረዶ መያዢያ ባልዲ\n ...
# 5      Crystal Glass Beverage Dispenser \n\n የመፈሳሽ መ...
# 8      Liquids/Juice Glass\n\nየጁስና ፈሳሽ መጠጦች መጠጫ\n ተለ...
# 11     \n\n Water proof Bed Cover\n\n ውሃ የማያስገባ የፍራሽ...
# 12     Ceramic Sausage/ Porridge Bowel\n\n ከሴራሚክ የተሰ...
# ...                                                 ...
# 4995  STAINLESS STEEL  COOKWARE SET\n18cm; 20cm; 22c...
# 4996                            Kenwood portable juicer
# 4997  Kenwood portable blender\nበቻርጅ የሚሰራ\n 380ሚሊ የሚ...
# 4998  PRANDELI ITALY COOKWARE\n ማብሰያና ወጥ ማቅረቢያ የሚሆኑ\...
# 4999                                       Garlic Press
#
#                            Date  \
# 2     2025-01-17 16:43:05+00:00
# 5     2025-01-16 20:20:43+00:00
# 8     2025-01-16 07:20:49+00:00
# 11    2025-01-15 05:13:17+00:00
# 12    2025-01-14 14:51:20+00:00
# ...                         ...
# 4995  2022-03-26 16:13:36+00:00
# 4996  2022-03-26 04:03:35+00:00
# 4997  2022-03-25 13:53:28+00:00
# 4998  2022-03-25 10:49:06+00:00
# 4999  2022-03-22 15:53:43+00:00
#
#                                         Cleaned_Message
# 2         \n\n የበረዶ መያዢያ ባልዲ\n  ኪሎ በረዶ ይይዛል\n ከወፍራም ...
# 5          \n\n የመፈሳሽ መጠጦች ማቅረቢያ\n በማንኛውም ወቅት የሚጠቀሙበ...
# 8       \n\nየጁስና ፈሳሽ መጠጦች መጠጫ\n ተለቅ ያለ  የሚይዝ\n\n ቱን ...
# 11     \n\n    \n\n ውሃ የማያስገባ የፍራሽ ልብስ\n\n ሜ  የትራስ ል...
# 12        \n\n ከሴራሚክ የተሰሩ የወጥ እና የገንፎ ሳህኖች\n በጣም ኳሊቲ...
# ...                                                 ...
# 4995      \n     ስፋት\n ለማብሰያና ወጥ ማቅረቢያ የሚሆኑ\n  ብር\n@...
# 4996
# 4997    \nበቻርጅ የሚሰራ\n ሚሊ የሚይዝ\nጆጉን ለመጠጫ መጨቀም ይቻላል\n ...
# 4998    \n ማብሰያና ወጥ ማቅረቢያ የሚሆኑ\n  በተለያየ መጠን\n አንደኛ ደ...
# 4999
#
# [3621 rows x 6 columns]

# %% [markdown]
# Save the Cleaned Data

# %%
# Save the Cleaned Data
preprocessor.save_data()
# Out:
# Cleaned text saved to ../../src/Data/clean_data/MerttEka_clean_data.csv.
