# %% [markdown]
# Import Necessary Modules

# %%
import sys
import os
import pandas as pd

# Add the path to the scripts directory
sys.path.append(os.path.abspath('../../scripts'))

# Import the DataPreprocessor class
from data_preprocessor import DataPreprocessor

# %% [markdown]
# Define Input and Output Paths and Initialize the DataPreprocessor

# %%
input_path = '../../src/Data/raw_data/Leyueqa-data.csv'
output_path = '../../src/Data/clean_data/leyueqa_clean_data.csv'

# Initialize the DataPreprocessor
preprocessor = DataPreprocessor(input_path, output_path)

# %% [markdown]
# Load the Data

# %%
preprocessor.load_data()

# Print the shape and DataFrame after loading the data
print("Shape before preprocessing:", preprocessor.df.shape)
print("Data after loading:")
preprocessor.df
# Out:
# Data loaded successfully.
# Checking for NaN values in the 'Message' column:
# Number of NaN values in 'Message' column: 1061
# Shape before preprocessing: (2340, 5)
# Data after loading:
#      Channel Title Channel Username    ID  \
# 0            ልዩ እቃ         @Leyueqa  6586
# 1            ልዩ እቃ         @Leyueqa  6585
# 2            ልዩ እቃ         @Leyueqa  6584
# 3            ልዩ እቃ         @Leyueqa  6583
# 4            ልዩ እቃ         @Leyueqa  6582
# ...            ...              ...   ...
# 2335         ልዩ እቃ         @Leyueqa  1207
# 2336         ልዩ እቃ         @Leyueqa   193
# 2337         ልዩ እቃ         @Leyueqa   172
# 2338         ልዩ እቃ         @Leyueqa   157
# 2339         ልዩ እቃ         @Leyueqa     1
#
#                                                 Message  \
# 0                                                   NaN
# 1     ⬇️⬇️⬇️9pcs Kitchen knife Set\n\n✔️1 ሞረድ\n\n✔️4...
# 2                                                   NaN
# 3     🔥💥Spark electronic gas lighter\n\nPrice⚡️ 750\...
# 4                                                   NaN
# ...                                                 ...
# 2335                                                NaN
# 2336                                                NaN
# 2337                                                NaN
# 2338                                                NaN
# 2339                                                NaN
#
#                            Date
# 0     2025-01-17 11:40:36+00:00
# 1     2025-01-17 11:40:35+00:00
# 2     2025-01-17 06:02:21+00:00
# 3     2025-01-17 06:02:21+00:00
# 4     2025-01-16 13:18:01+00:00
# ...                         ...
# 2335  2020-09-11 11:31:22+00:00
# 2336  2018-11-04 16:06:40+00:00
# 2337  2018-11-01 15:13:35+00:00
# 2338  2018-10-27 14:45:29+00:00
# 2339  2018-08-02 07:30:19+00:00
#
# [2340 rows x 5 columns]

# %% [markdown]
# Preprocess the Data

# %%
preprocessor.preprocess_data()

# Print the shape and DataFrame after preprocessing the data
print("Shape after preprocessing:", preprocessor.df.shape)
print("Data after preprocessing:")
preprocessor.df
# Out:
# Data preprocessing completed.
# Shape after preprocessing: (1279, 6)
# Data after preprocessing:
#      Channel Title Channel Username    ID  \
# 1            ልዩ እቃ         @Leyueqa  6585
# 3            ልዩ እቃ         @Leyueqa  6583
# 5            ልዩ እቃ         @Leyueqa  6581
# 9            ልዩ እቃ         @Leyueqa  6577
# 10           ልዩ እቃ         @Leyueqa  6576
# ...            ...              ...   ...
# 2328         ልዩ እቃ         @Leyueqa  2626
# 2329         ልዩ እቃ         @Leyueqa  2608
# 2330         ልዩ እቃ         @Leyueqa  2462
# 2333         ልዩ እቃ         @Leyueqa  2172
# 2334         ልዩ እቃ         @Leyueqa  2072
#
#                                                 Message  \
# 1     9pcs Kitchen knife Set\n\n1 ሞረድ\n\n4 በተለያየ መጠን...
# 3     Spark electronic gas lighter\n\nPrice 750\n   ...
# 5     \n\n Kitchen Expert 3 in 1 Chopper and Garlic ...
# 9     2 ድስቶች + 1 ወጥ ማቅረቢያ + 1 መጥበሻ \n  የማይዙ የማያሳርሩ ለ...
# 10     5-in-1 Trouser Hanger የሱሪ ማስቀመጫ\n የሱሪ ማስቀመጫ ሱ...
# ...                                                 ...
# 2328   Electric Hair Styling Hot Comb\n             ...
# 2329  Vacuum sealer ኦሪጅናል \nላስቲክ ዉስጥ ያለዉን አየር ስቦ ማሸግ...
# 2330  ትክክለኛ አድራሻችንን በጎግል ማፕ ሊንኩን ተጭነዉ ሱቆቻችን ድረስ መምጣት...
# 2333  Braided Hair Machine \nLet Children  Be Beauti...
# 2334  Pedi Mate\nGently Removes Callous, Dry Skin\n1...
#
#                            Date  \
# 1     2025-01-17 11:40:35+00:00
# 3     2025-01-17 06:02:21+00:00
# 5     2025-01-16 13:18:01+00:00
# 9     2025-01-16 10:08:01+00:00
# 10    2025-01-16 08:31:59+00:00
# ...                         ...
# 2328  2022-05-30 07:46:18+00:00
# 2329  2022-05-24 05:30:53+00:00
# 2330  2022-03-10 08:36:33+00:00
# 2333  2021-11-05 10:55:22+00:00
# 2334  2021-10-04 06:14:01+00:00
#
#                                         Cleaned_Message
# 1     \n\nሞረድ\n\nበተለያየመጠንቢላዎች\n\nመቀስ\n\nመከትከቻ\n\nከማስ...
# 3     \n\n\n ቻናላችንንለጓደኛዎሸርማድረግዎንአይርሱ\n           \n ...
# 5     \n\n\n\nሊትርየሚይዙሁለትቋቶች\nአንዱየብረትአንዱደግሞወፍራምጠርሙስ\n...
# 9     ድስቶች+ወጥማቅረቢያ+መጥበሻ\n የማይዙየማያሳርሩለይታውቡየሆኑ\n      ...
# 10    የሱሪማስቀመጫ\nየሱሪማስቀመጫሱሪዎወይምልብስዎባለበትንፅህናውእንደተጠበቀሳይ...
# ...                                                 ...
# 2328  \nኮድ\n\n\n\n\n\n\n\nዋጋ፦ብርከነፃዲሊቨሪጋር\n\n#ክፍያዎንበሞ...
# 2329  ኦሪጅናል\nላስቲክዉስጥያለዉንአየርስቦማሸግየሚችልየላስቲክማሸጊያ\nፍራፍሬ፣...
# 2330  ትክክለኛአድራሻችንንበጎግልማፕሊንኩንተጭነዉሱቆቻችንድረስመምጣትይችላሉ\nቁጥ...
# 2333  \n\n°\n\n\n\n\n\n\n\n\n\nአድራሻዎቻችንአአቁጥርልደታባልቻሆስ...
# 2334                   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n
#
# [1279 rows x 6 columns]

# %% [markdown]
# Save the Cleaned Data

# %%
# Save the Cleaned Data
preprocessor.save_data()
# Out:
# Cleaned text saved to ../../src/Data/clean_data/leyueqa_clean_data.csv.
